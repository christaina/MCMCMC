# %%
import sys
# %load_ext autoreload
# %autoreload 2
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import mlp_sequential

# %%
data_p = '../data_static_2.txt'

# %%
data = np.loadtxt(data_p)

# %%
X = data[:,1:-1]

# %%
y = data[:,-1]

# %%
mlp = mlp_sequential.MLP(n_iter=100000)

# %%
mlp.partial_fit(n_features=3,hidden=2)

# %%
mlp.partial_fit(X,y)

# %%
mlp.coef_
# Out:
# [array([[-0.02370458, -0.02216619],
#         [-0.04977286, -0.00729235]]), array([[ 0.25531502,  0.26028413],
#         [ 0.23165966,  0.24261052]])]

# %%
mlp.score(X,y)
# Out:
# [[ 0.68471055  0.68673005]
#  [ 0.68494447  0.68696876]
#  [ 0.68500376  0.6870295 ]
#  [ 0.68558771  0.68762693]
#  [ 0.6856201   0.68766039]
#  [ 0.68564829  0.68768921]
#  [ 0.68500962  0.68703564]
#  [ 0.68482464  0.68684661]
#  [ 0.6848544   0.68687802]
#  [ 0.68536165  0.68739653]
#  [ 0.68564695  0.68768949]
#  [ 0.68569565  0.68773787]
#  [ 0.68482956  0.68685165]
#  [ 0.68483558  0.68685738]
#  [ 0.68497876  0.68700389]
#  [ 0.68554725  0.68758683]
#  [ 0.68584127  0.68788674]
#  [ 0.68560843  0.68764785]
#  [ 0.68506593  0.68709434]
#  [ 0.68485546  0.68687849]
#  [ 0.68506726  0.68709461]
#  [ 0.68540193  0.68743906]
#  [ 0.68566091  0.68770246]
#  [ 0.68557985  0.68762009]
#  [ 0.68504735  0.68707523]
#  [ 0.68475897  0.68677996]
#  [ 0.68481819  0.68684061]
#  [ 0.6855729   0.68761276]
#  [ 0.6855887   0.68762934]
#  [ 0.68556341  0.68760267]
#  [ 0.68491577  0.68693969]
#  [ 0.68489279  0.686917  ]
#  [ 0.68491688  0.68694149]
#  [ 0.68551213  0.68755029]
# ...
